# %%
# ANSWER 1:
#exception class refers to the base class for all the exception
try:
    f=open("test.txt",'r')
    f.read()
except Exception as e:
    print(e)
except FileNotFoundError as e:
    print(e)
except TypeError as e:
    print(e)

# %%
# ANSWER 2:
import inspect as ipt
def tree_class(cls,ind=0):
    print('_' * ind,cls.__name__)
    for k in cls.__subclasses__():
        tree_class(k,ind + 3)
print("inbuilt excepton is:")
ipt.getclasstree(ipt.getmro(BaseException))
tree_class(BaseException)
# Out:
# inbuilt excepton is:
#  BaseException
# ___ Exception
# ______ TypeError
# _________ FloatOperation
# _________ MultipartConversionError
# ______ StopAsyncIteration
# ______ StopIteration
# ______ ImportError
# _________ ModuleNotFoundError
# _________ ZipImportError
# ______ OSError
# _________ ConnectionError
# ____________ BrokenPipeError
# ____________ ConnectionAbortedError
# ____________ ConnectionRefusedError
# ____________ ConnectionResetError
# _______________ RemoteDisconnected
# _________ BlockingIOError
# _________ ChildProcessError
# _________ FileExistsError
# _________ FileNotFoundError
# _________ IsADirectoryError
# _________ NotADirectoryError
# _________ InterruptedError
# ____________ InterruptedSystemCall
# _________ PermissionError
# _________ ProcessLookupError
# _________ TimeoutError
# _________ UnsupportedOperation
# _________ itimer_error
# _________ herror
# _________ gaierror
# _________ SSLError
# ____________ SSLCertVerificationError
# ...

# %%
#ANSWER 3:
"""YES"""
try:
    10/0
except ZeroDivisionError as e:
    print(e)
try:
    f=open("test.txt",'r')
    f.read()
except FileNotFoundError as e:
    print(e)
# Out:
# division by zero

# %%
# ANSWER 4:
"""lookupError exception isthe base class for Error raised when something can't be found"""
try:
    d={"key": "sachin",1:[1,3,4,5,6]}
    print(d["key2"])
except KeyError as e:
    print(e)
# Out:
# 'key2'

# %%
try:
    l=[2,3,4,5]
    print(l[6])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
#ANSWER 5:
""" PYTHON import error(moduleNotFoundError) indicates that your tried to import a module that python doesn't find"""
# Out:
# " PYTHON import error(moduleNotFoundError) indicates that your tried to import a module that python doesn't find"

# %%
#ANSWER 6:
# how to handle an Arbitray exception....
#catch multiple exception in one except block
#handling multiiple exception with one except block..
#_re_ raising Exception in python..
#when to use the else class clause...
#make use of (finally_clause)
#use the as keyword to catch specific Exception types
